# %% [markdown]
# # Convex Optimization: Optimal Transport
#
# **Prerequisites**
#
# - Linear Algebra
# - Calculus
# - Convex Optimization: Theoretical Foundations
# - Convex Optimization: Linear Programs
#
#
# **Outcomes**
#
# - Understand the format of a linear program
# - Know how to formulate a linear program in standard form
# - Understand and interpret slack variables
# - Know how to set up and solve linear programs

# %% [markdown]
# **Outline**
#
# - Learn from Fields medalist Cédric Villani
# - Application

# %% [markdown]
# ## Optimal Transport from Cédric Villani
#
# - The piano transport problem was basic example of field called optimal transport
# - We'll learn more about this, first by watching lecture by Cédric Villani (2010 Fields Medalist)

# %%
from IPython.lib.display import YouTubeVideo
 
YouTubeVideo('zo46TEp6FB8', 1400, 800, start=1685, end=2550)

# %%
YouTubeVideo?
# Out:
# Init signature: YouTubeVideo(id, width=400, height=300, **kwargs)
# Docstring:
# Class for embedding a YouTube Video in an IPython session, based on its video id.
#
# e.g. to embed the video from https://www.youtube.com/watch?v=foo , you would
# do::
#
#     vid = YouTubeVideo("foo")
#     display(vid)
#
# To start from 30 seconds::
#
#     vid = YouTubeVideo("abc", start=30)
#     display(vid)
#
# To calculate seconds from time as hours, minutes, seconds use
# :class:`datetime.timedelta`::
#
#     start=int(timedelta(hours=1, minutes=46, seconds=40).total_seconds())
#
# Other parameters can be provided as documented at
# https://developers.google.com/youtube/player_parameters#Parameters
#
# When converting the notebook using nbconvert, a jpeg representation of the video
# will be inserted in the document.
# File:           ~/anaconda3/envs/css/lib/python3.8/site-packages/IPython/lib/display.py
# Type:           type
# Subclasses:

# %% [markdown]
# ## Duality
#
# - build on  Villani's mention of duality
# - Show example where dual gives prices
